# %% [markdown]
# <a href="https://colab.research.google.com/github/RifleB-1311/Baitap1-nhom2/blob/main/thaotactaptin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1: Viết chương trình thực hiện các yêu cầu sau:
# - Nhập một chuỗi kí tự từ bàn phím
# - Nhập tên tập tin từ bàn phím
# - Lưu chuỗi ký tự ở trên vào tập tin.

# %%
tenchuoi = input("Nhập 1 chuỗi: ")
tentep = input("Nhập tên tệp: ") + ".txt"
luu=open(tentep,"w")
luu.write(chuoi1)
luu.close()
# Out:
# Nhập 1 chuỗi: bách
# Nhập tên tệp: Bach

# %% [markdown]
# Bài 2: Viết chương trình thực hiện các yêu cầu sau:
# - Nhập tên tập tin từ bàn phím
# - Đọc nội dung tập tin và in ra màn hình

# %%
tentaptin=input("Mời nhập tên tập tin cần đọc:")+".txt"
f=open(tentaptin,"r")
doc=f.read()
print(doc)
# Out:
# Mời nhập tên tập tin cần đọc:Bach
# bach

# %% [markdown]
# Bài 3: Viết chương trình thực hiện các yêu cầu sau:
# - Nhập tên tập tin từ bàn phím
# - Nhập một chuỗi kí tự vào từ bàn phím
# - Ghi chuỗi kí tự này vào cuối tập tin ở trên

# %%
ten=input("Mời nhập tên tập tin:")+".txt"
chuoi=input("Mời nhập chuỗi:")
f=open(ten,"a")
ghi=f.write(chuoi)
f.close()
# Out:
# Mời nhập tên tập tin:Bach
# Mời nhập chuỗi:trường đại học huế.

# %% [markdown]
# Bài 4: Viết chương trình thực hiện các yêu cầu sau:
# - Đọc tập tin ở bài 3 và ghi kết quả ra màn hình

# %%
f= open("Bach.txt","r")
doc1=f.read()
print(doc1)
# Out:
# bach lớp AI &DS lớp K2 trường đại học huế.

# %% [markdown]
# Bài 5: Viết chương trình thực các yêu cầu sau:
# - Sinh ngẫu nhiên 1 danh sách gồm 1000 số nguyên trong khoảng từ [-1000, 1000]
# - Nhập tên tập tin từ bàn phím
# - Ghi danh sách trên vào tập tin theo quy tắc:
#
# o 10 số trên một hàng
#
# o Các số phân tách nhau bởi dấu phẩy (,)
#
# - Đọc nội dung tập tin ở trên và in ra màn hình theo quy tắc:
#
# o 10 số trên một hàng
#
# o Các số phan tách nhau bởi dấu tab.

# %%
import random
danhsach = []
check = 0
for i in range(1000):
    danhsach.append(random.randint(-1000, 1000))
tenfile = input("tên file: ")
for i in danhsach:
    if check < 9:
        f = open(tenfile, 'a')
        chuoikytu = str(i)+','
        f.write(chuoikytu)
        f.close()
        check +=1
    else:
        f = open(tenfile, 'a')
        f.write(str(i)+"\n" )
        f.close()
        check = 0
f = open(tenfile, 'r')
a = f.readlines()
for i in a:
    print(i)
f.close()
# Out:
# tên file: Bach
# 200,98,923,967,6,738,-305,522,-66,-281
#
# 604,-154,-383,530,955,-769,26,-557,159,390
#
# -195,-927,-779,-561,-70,-640,-543,-392,-431,199
#
# 634,-547,-265,483,-403,825,460,329,-267,-171
#
# -411,313,-754,-447,975,912,-980,-183,-259,627
#
# 225,-128,654,9,311,735,-669,686,892,759
#
# -208,201,-808,241,90,-212,857,-586,-557,-319
#
# -182,-845,138,-697,-592,-831,730,727,-941,650
#
# -236,-590,-380,-286,665,774,-223,-346,-458,-60
#
# 663,374,671,-743,-224,953,423,-437,-858,-686
#
# -548,-560,-382,-769,-235,837,-497,83,-336,-402
#
# -800,-838,357,929,17,-661,221,587,428,341
#
# -884,573,797,-675,212,-126,363,30,-522,732
#
# 671,976,-228,-388,420,37,-774,-974,-654,-122
#
# 223,17,113,622,459,125,-591,50,-1,-326
#
# 211,-424,-985,-790,988,-10,360,-705,270,-44
#
# -678,951,-968,779,-403,-980,577,-161,351,288
#
# -976,98,525,-1000,512,-781,-597,-919,252,814
#
# 788,478,353,-678,190,-275,-42,-906,-150,842
#
# 468,-878,-628,-995,-796,-386,954,900,58,-990
#
# 861,-169,-49,-402,-551,4,-792,798,966,241
#
# -450,351,414,-377,-580,-810,612,938,470,-408
#
# 434,-988,399,639,268,871,-641,-365,-611,-678
#
# -701,371,562,766,-581,-226,113,-991,-409,-40
#
# 803,730,-394,-99,763,477,0,-828,562,-996
#
# 643,79,-433,622,-834,301,-610,-647,-303,-450
#
# -530,58,572,-651,925,244,-596,254,-372,955
#
# 733,-24,-76,900,354,-723,-980,604,440,346
#
# -243,417,-636,515,399,503,-368,245,-573,251
#
# 816,368,289,-401,947,600,345,519,197,212
#
# -508,-924,-990,-712,144,-586,958,-520,916,767
#
# -544,-393,-43,769,221,-108,-237,-906,978,-48
#
# 954,-461,147,-494,-272,-150,-155,671,-135,23
#
# 467,648,-332,288,732,-360,-598,-584,295,-495
#
# -68,142,-525,-424,375,48,-774,61,212,-512
#
# -101,-574,-170,-72,-296,899,79,213,504,375
#
# 34,-179,634,524,-613,-273,-586,184,-69,311
#
# -125,95,65,180,627,485,759,548,52,219
#
# 184,-346,-428,-475,-766,98,964,528,-384,-76
#
# 920,823,718,-115,-747,-345,-583,-560,-47,-252
#
# -869,966,587,515,115,-373,-811,154,-531,371
#
# 772,671,-96,628,467,-847,-228,559,-559,349
#
# 387,-843,700,-525,-36,503,-322,651,-641,869
#
# 438,-340,410,340,-489,-782,111,291,558,146
#
# 935,-159,655,347,-770,-302,439,994,-52,-831
#
# -342,891,-391,671,-821,-909,42,289,-797,391
#
# 210,-210,-957,596,240,361,-763,676,-846,35
#
# 892,21,-377,27,509,-271,401,-138,-607,585
#
# 671,390,593,92,281,348,-862,-508,-968,15
#
# -588,-680,-915,-994,-351,346,776,599,-408,-264
#
# -46,-690,-915,31,664,-721,229,-812,-642,-248
#
# 731,-25,-121,361,351,-659,805,851,-654,-391
#
# 580,-316,-154,176,-106,55,-732,636,906,-126
#
# -357,383,-232,-906,419,-225,-440,-863,-598,-689
#
# 337,46,-148,-303,-877,976,994,-407,357,763
#
# 880,-41,443,30,98,-855,-286,-742,-97,718
#
# 608,-359,-516,610,122,-508,148,-758,662,250
#
# 433,-642,-101,-812,-493,459,990,-902,-579,-236
#
# 249,-800,-172,940,-715,45,179,831,-213,300
#
# -219,-667,331,-1000,-793,-182,477,-601,-42,-493
#
# 120,777,-99,-523,892,-176,635,464,-558,-893
#
# 92,-758,-66,-963,-291,792,181,146,481,-214
#
# -784,-968,720,517,239,414,-394,568,-893,758
#
# -464,388,939,279,963,193,-779,220,475,1
#
# -81,-634,519,-295,551,-478,-464,777,178,434
#
# -856,-949,44,-668,-874,352,-364,-522,836,227
#
# 940,-833,-480,-750,172,-755,-818,-142,-431,-491
#
# 596,-200,-46,729,770,299,466,914,58,-78
#
# -297,45,-387,-800,120,180,-886,805,-740,716
#
# -307,-544,-782,840,441,291,-208,602,976,-869
#
# 397,916,870,836,-923,705,-739,728,654,292
#
# 279,184,-514,448,-912,-524,-657,738,769,221
#
# 137,-518,-966,422,-662,272,-853,-440,378,305
#
# 84,-323,944,-173,666,904,-100,767,-413,410
#
# 802,47,-226,-518,398,285,-338,274,840,-969
#
# 882,-835,460,124,-321,-324,898,21,-906,-209
#
# 484,-50,-170,781,-896,227,509,227,-172,622
#
# 462,-254,-353,-955,495,-382,-580,-138,-31,173
#
# 80,999,43,-423,-566,-389,866,425,-784,361
#
# 729,-873,-133,203,517,-599,915,-148,-707,-43
#
# -458,215,311,-490,919,522,-96,-200,945,-755
#
# -535,2,544,80,-207,817,-464,-683,8,903
#
# 698,936,372,-419,658,-629,628,312,-433,-589
#
# -450,-556,-708,-391,-472,-659,-959,131,-522,261
#
# -370,-868,652,-821,-126,-542,694,-466,109,-660
#
# -433,-409,-737,-44,-187,-260,694,482,-364,114
#
# -165,606,910,-640,-738,-509,400,965,-393,54
#
# 841,686,323,85,81,-574,-856,699,-792,-174
#
# 611,-328,-282,-893,-660,-449,-995,119,-343,-516
#
# -351,187,-842,-598,79,-334,-697,-631,177,-298
#
# -658,-952,798,82,-586,-196,-986,-616,553,110
#
# 403,-890,933,-135,-671,972,-527,107,-463,-271
#
# -13,-389,-73,357,-531,-382,286,-590,-634,45
#
# -494,-569,-58,713,893,301,433,-985,632,-860
#
# 182,-743,-761,500,834,-33,-524,-26,-412,921
#
# -572,-114,651,560,-642,-665,573,572,-918,90
#
# 947,660,383,-124,-915,49,41,146,422,547
#
# -128,423,84,-150,-493,196,-452,462,168,868
#
# 512,181,-424,910,153,814,-22,110,873,-110
#
# -487,-870,979,-706,343,-534,886,858,-311,156
#
# 794,-887,617,348,134,183,301,381,-577,-958
#
# 965,-428,207,206,358,701,778,549,-442,-822
#
# 992,-93,-434,-441,434,141,-50,-822,-569,650
#
# -353,373,-688,536,-693,-961,-110,-533,-890,-834
#
# 686,-82,633,293,318,493,820,857,-504,710
#
# 633,96,-578,722,-125,-312,-303,-893,-182,-953
#
# -255,746,473,-775,201,-618,-864,85,-216,130
#
# -530,-955,-151,823,-843,49,-162,-518,885,316
#
# 912,157,160,123,-206,-313,-913,200,295,505
#
# 459,-492,881,-909,991,-662,314,-672,620,25
#
# -22,-136,-985,-486,182,-147,24,216,-491,-151
#
# 452,60,-116,-133,-854,-178,-675,953,-220,275
#
# -481,901,-610,18,788,108,138,695,882,-13
#
# -266,-448,-170,-602,-891,-165,445,36,94,591
#
# 226,204,532,-707,-685,-361,-989,812,236,-583
#
# 737,995,513,153,-866,664,691,-589,-300,68
#
# -109,229,-517,388,508,-206,71,484,-507,-794
#
# 21,334,-800,-295,71,274,-908,-447,453,734
#
# -319,-421,-330,549,-630,338,-904,-52,-494,-427
#
# -199,79,221,-548,-356,-220,-869,434,-806,-225
#
# -761,750,-532,20,-342,-124,-120,88,-385,-537
#
# -330,-858,-298,-155,-494,-651,79,357,99,-358
#
# 476,-365,324,440,59,-399,640,880,384,-703
#
# 99,78,-546,-75,247,16,371,224,-309,-348
#
# -861,889,138,-156,-378,-493,43,525,-503,160
#
# -576,385,944,167,71,-251,-908,159,351,-985
#
# 738,-42,-209,907,678,-697,-754,988,-400,-66
#
# -326,352,305,697,-581,4,210,685,-507,-244
#
# -449,874,588,584,-194,-566,973,-332,529,245
#
# -64,841,347,-95,-236,-337,-717,438,587,363
#
# -586,757,-348,995,911,-539,-353,-368,-479,-194
#
# -114,-809,966,-469,90,75,-853,-250,265,-68
#
# -519,996,878,66,781,245,-549,-528,-303,71
#
# -465,-387,216,-565,619,-649,-580,956,-892,-294
#
# -109,-708,-390,255,-469,-164,-643,360,-388,933
#
# 546,-128,-911,-559,-368,80,-734,-352,807,-230
#
# 616,-994,147,776,-951,-785,-916,-142,-418,66
#
# -140,-624,425,-542,360,436,-614,-914,-373,-582
#
# -2,904,757,86,-693,-803,386,-22,-328,-367
#
# -529,92,246,343,-224,289,118,862,882,-880
#
# -767,336,422,373,-645,6,-810,-743,-756,-848
#
# -635,521,-425,270,244,489,-579,540,-909,705
#
# -167,-680,264,-189,-255,12,-999,563,911,584
#
# 492,262,-296,-230,-358,-533,-741,-436,640,-118
#
# 686,-271,-657,884,-513,-507,-687,-746,-29,-764
#
# 831,558,141,-223,-958,-349,742,709,-399,-960
#
# 575,0,-968,534,658,471,659,273,-570,736
#
# -540,-133,-470,-511,95,-652,802,-103,-202,-199
#
# 385,-747,-207,-451,-485,728,-915,29,820,-916
#
# -303,826,-922,-527,710,596,201,784,34,-123
#
# 177,-308,504,-881,924,657,-74,-530,970,-985
#
# -172,932,71,304,361,-551,350,702,686,-444
#
# 684,-946,-933,-586,-821,812,-246,-678,929,-125
#
# 341,688,382,-364,-774,-265,869,434,-927,489
#
# 950,-886,-701,-365,-162,-933,-622,472,-922,-262
#
# -940,195,-854,156,-973,-356,-748,807,181,327
#
# 697,-2,-852,-618,58,-146,774,934,-244,-406
#
# 235,-485,-961,-109,-872,421,-593,391,195,-651
#
# -840,-343,-66,462,-586,851,-480,36,877,-733
#
# -380,-22,601,-546,727,-812,251,709,588,267
#
# -727,575,-746,-508,284,-854,-484,-715,783,-521
#
# -843,761,664,-58,-133,600,-825,903,936,233
#
# -325,-662,107,-432,219,878,-101,636,702,89
#
# 810,-134,-135,972,932,851,-528,782,447,574
#
# 839,-232,976,-189,-550,964,-106,199,-384,408
#
# 918,502,243,-215,643,-735,490,-331,461,-858
#
# 266,-925,-835,-853,342,-174,-464,536,343,101
#
# 172,-37,242,-26,396,-179,-897,197,775,1
#
# 226,206,499,142,-985,-463,-669,517,-872,-866
#
# -640,89,97,-730,-340,-489,542,577,-928,-86
#
# -643,-407,-370,-911,883,375,779,652,192,-172
#
# 238,965,-63,134,-863,766,942,440,-361,442
#
# 278,-758,-92,990,-17,-762,-236,583,465,-695
#
# 614,149,-348,942,727,-82,-636,426,538,-198
#
# -154,447,667,29,-472,55,-798,926,-318,19
#
# 400,-321,503,-596,-284,692,-405,614,-511,-363
#
# 798,-600,153,200,-493,381,754,66,-441,38
#
# -4,-720,943,603,-540,918,-300,-965,-856,-161
#
# -694,-136,126,-534,935,-691,177,502,-735,482
#
# 247,186,-789,-318,-80,734,-421,285,620,-895
#
# -470,748,129,642,-660,588,-534,-932,738,-814
#
# -768,-335,-865,-841,762,-966,626,-211,-711,-116
#
# 33,-920,-494,-800,-669,768,-618,197,-805,-459
#
# -608,992,278,522,-527,111,45,-769,-989,499
#
# 72,-673,-626,238,667,987,428,-404,-238,659
#
# 763,-182,882,534,245,-684,443,-185,86,-967
#
# -90,-840,72,-660,-176,-144,-66,-447,105,556
#
# -837,200,-763,608,210,-116,874,772,806,-35
#
# -944,-973,-928,81,676,386,728,-673,-171,-950
#
# -835,243,364,29,-642,303,487,57,-923,928
#
# -513,-428,483,-449,-960,-634,5,215,-423,-526
#
# -458,847,-731,-317,-560,776,-773,-245,-85,623
#
# -318,-22,879,-627,-315,998,-572,-136,738,-858
#
# -359,73,-49,-105,-922,-361,505,312,370,-657
#
# 751,-368,844,-816,130,497,12,630,924,413
#
# 450,-258,-455,333,403,-814,882,2,-975,16
#
# 92,-267,942,-332,955,902,991,-854,901,55
#
# 958,-710,-343,-716,-128,978,103,-231,759,730
#
# 107,982,-821,875,904,852,-300,-973,-894,245
#
# 147,899,-476,-168,262,430,-821,787,-84,352
#
# -659,-635,-614,15,293,425,-931,-789,-250,-890
#
# 278,-676,-397,706,-632,-853,-353,-150,268,-24
#
# -968,-280,-654,-225,-999,636,-937,-447,752,-892
#
# -430,-798,626,-567,213,-907,263,-367,-832,464
#
# 764,827,-406,903,-738,-505,-869,-663,-946,441
#
# 969,-534,-901,114,-42,959,-316,936,-239,-307
#
# 669,687,-908,-97,12,-938,-918,-133,-695,-30
#
# -474,656,-103,936,-75,527,417,354,-352,-188
#
# 381,200,260,-573,818,-692,611,961,56,-246
#
# 767,785,-297,-26,-840,717,704,333,-23,-71
#
# -150,-473,-980,75,-161,984,-484,399,-918,515
#
# -136,-226,-636,699,461,-585,-394,-791,66,-56
#
# -818,-715,-55,672,-467,-719,-6,830,-293,817
#
# -591,-285,-851,461,-383,277,368,-810,994,-63
#
# 439,-555,811,-822,-320,-965,-874,516,-456,-962
#
# -232,541,50,-218,-855,802,-284,-54,917,671
#
# -214,533,82,-436,524,131,-481,800,-608,766
#
# 708,-528,-189,566,-655,-188,-233,-706,6,765
#
# 999,254,517,-927,-923,558,-891,-549,-431,818
#
# -150,-462,200,-89,-352,-753,-364,325,-638,329
#
# 480,-922,258,182,-69,-77,832,174,739,91
#
# 935,-183,-699,-3,219,224,-822,-168,945,-933
#
# -435,664,-91,530,-651,814,741,456,32,-276
#
# 0,-20,298,-122,-863,-483,-484,-126,-834,759
#
# 634,255,943,-241,642,-75,444,-582,-403,-384
#
# -8,594,917,937,-865,-530,-247,-520,-21,351
#
# -233,443,-332,123,819,870,-94,-851,466,500
#
# -882,187,-690,-482,-39,499,-352,-441,-367,443
#
# -279,-410,-686,353,774,-738,-734,-394,828,-573
#
# -800,-5,686,938,-646,422,485,979,-829,-520
#
# 576,-16,30,-579,900,379,135,-167,77,174
#
# 136,-633,674,-674,-867,620,437,-317,692,992
#
# -143,-430,-607,-460,281,-870,278,441,-575,-915
#
# -669,916,165,-794,61,556,446,-93,140,-34
#
# -997,-114,-815,670,312,751,945,710,734,-565
#
# -341,321,197,-298,-860,-265,-648,767,355,-97
#
# -821,74,148,-913,-179,-268,-923,-6,837,-938
#
# 349,485,-938,958,-267,715,118,-122,-491,-202
#
# 358,-655,-978,720,956,381,114,-158,434,262
#
# 416,784,-33,9,8,-413,230,596,-858,-871
#
# -743,345,150,-275,209,-734,-369,406,-11,-663
#
# -698,-783,-575,-841,-227,-540,-298,-328,-518,-881
#
# -107,-704,393,853,-221,730,-360,998,422,986
#
# 133,-283,-655,41,-190,-114,850,108,-378,-444
#
# 208,301,-281,978,-351,-947,-101,345,928,706
#
# 741,396,869,486,-91,694,430,744,750,957
#
# 29,-285,959,-69,-624,-802,38,348,-112,65
#
# -363,-237,-12,-709,870,38,469,124,-130,-836
#
# -924,828,856,342,714,876,932,828,772,-489
#
# -347,519,-552,-318,-700,-507,721,165,-212,478
#
# 628,519,33,-200,-555,-962,486,-171,384,380
#
# 927,525,523,859,659,-762,229,623,-283,855
#
# -302,-845,408,-304,-610,-550,-622,-91,491,115
#
# -239,53,797,-17,606,-920,-658,101,-343,-458
#
# 542,-19,665,181,-44,-494,826,-83,31,-266
#
# 110,-905,975,-778,-532,79,283,669,-725,-198
#
# 889,537,-700,-73,-853,-415,726,751,355,-677
#
# -182,-602,-169,-352,-732,-180,-123,-989,887,799
#
# -998,-633,285,-5,-162,-943,864,-196,-925,-104
#
# 752,-43,180,994,677,-820,523,47,-539,599
#
# 1000,949,-367,-179,169,877,147,-811,-74,-238
#
# 933,-678,-407,807,-896,-780,-686,-499,161,-761
#
# 10,-354,127,308,-403,-514,-659,-50,-627,-778
#
# -641,-461,349,930,-365,-575,-36,-385,617,-678
#
# 72,-674,700,-960,-705,393,323,914,-381,604
#
# -585,356,-425,269,-339,904,-436,75,-326,-666
#
# 466,-807,985,-217,786,913,-282,621,-999,802
#
# 465,174,636,137,163,-882,971,-23,88,-742
#
# 937,401,-421,-359,-574,791,799,769,748,343
#
# -561,935,829,-429,-32,237,-558,-762,-90,223
#
# 973,47,907,721,-941,-176,-518,465,-446,43
#
# -756,-528,192,-824,-650,7,-890,-275,300,813
#
# 243,263,596,817,163,-971,87,330,-40,82
#
# -151,-433,-723,-143,-280,539,941,489,359,303
#
# 130,-353,875,180,149,709,-558,-708,-799,-881
#
# 72,774,-917,637,846,-317,-569,33,243,-137
#
# 504,61,-360,-336,-950,-886,481,-922,921,-772
#
# -954,142,181,-459,-168,-386,595,-865,-526,-805
#
# -981,420,-879,747,809,-89,-988,-536,-129,-63
#
# 268,-618,-405,806,-441,979,504,-214,423,-743
#
# 257,-493,-258,-378,180,758,-822,651,187,-196
#
# -542,-618,-507,-367,301,748,-636,68,-250,-122
#
# -296,310,-695,301,-281,948,-587,603,-89,319
#
# -220,643,276,468,795,920,-9,720,-227,777
#
# -517,-153,-92,-65,972,445,-16,91,141,830
#
# -132,40,-550,463,529,-32,93,-877,809,-891
#
# 700,735,215,-735,264,-684,961,96,720,-2
#
# 665,-317,-962,-157,990,836,16,630,-366,903
#
# -889,757,508,-570,-881,680,865,-709,250,-520
#
# -239,176,-260,333,510,-519,547,-509,320,531
#
# -399,-779,-701,492,21,398,-20,-55,-47,-783
#
# -468,760,-639,-237,495,-874,-984,-807,762,-574
#
# 336,-727,-854,-579,-174,-390,441,289,897,-542
#
# -33,719,789,689,807,-818,-957,249,-259,-566
#
# 625,-832,-286,558,-567,-462,878,-937,-651,-242
#
# -183,-636,0,-572,-419,289,485,916,614,348
#
# 485,183,-892,685,811,259,-26,280,-346,-452
#
# 288,-903,618,681,969,628,-72,146,83,-689
#
# 212,245,536,99,-846,521,-988,-106,600,-216
#
# 208,878,-449,-546,339,136,-935,671,-403,-454
